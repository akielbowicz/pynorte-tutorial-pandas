# %% [markdown]
# # Indice

# %% [markdown]
# [-1 - Usted está aquí](Indice.ipynb)
#
# [0 - Introduccion a Jupyter](0-Introduccion_a_Jupyter.ipynb)
#
# [1 - Estructuras de datos](1-Estructuras_de_datos.ipynb)
#
# [2 - Indexado y selección de datos](2-Indexado_y_seleccion_de_datos.ipynb)
#
# [3 - Gráficos](3-Graficos.ipynb)
#
# [4 - Transformación de datos](4-Transformacion_de_datos.ipynb)
#
# [5 - Agrupación y agregación](5-Agrupacion_y_agregacion.ipynb)
#
# [6 - Unión de datos](6-Union_de_datos.ipynb)
#
# [7 - Presentación](7-Presentacion.ipynb)
#
# [∞ - Por donde continuar ...](∞-Por_donde_continuar.ipynb)

# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.util.testing.makeDataFrame()
df.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_a6e508b2_6554_11e9_bc92_35c4022e5c50row8_col1 {
#             background-color:  yellow;
#         }    #T_a6e508b2_6554_11e9_bc92_35c4022e5c50row8_col2 {
#             background-color:  yellow;
#         }    #T_a6e508b2_6554_11e9_bc92_35c4022e5c50row13_col3 {
#             background-color:  yellow;
#         }    #T_a6e508b2_6554_11e9_bc92_35c4022e5c50row22_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_a6e508b2_6554_11e9_bc92_35c4022e5c50" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a6e508b2_6554_11e9_bc92_35c4022e5c50level0_row0" class="row_heading level0 row0" >PKiw9f0AbE</th>
# ...

# %%
df.plot(kind='bar')
